# %% [markdown]
# <a href="https://colab.research.google.com/github/yanghyeon408/OpenCV/blob/master/01_%EC%9D%B4%EB%AF%B8%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# # OPEN CV 1.1 이미지 불러오기

# %%
lena_img = cv2.imread("lena.jpg")
print(lena_img.shape)
type(lena_img)
# Out:
# (512, 512, 3)
# numpy.ndarray

# %% [markdown]
# # 1.2 이미지 보기

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(lena_img)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FEB7516E780>

# %%
import cv2

fname = 'logo.png'

original = cv2.imread(fname, cv2.IMREAD_COLOR)
gray = cv2.imread(fname, cv2.IMREAD_GRAYSCALE)
unchange = cv2.imread(fname, cv2.IMREAD_UNCHANGED)

cv2_imshow(original)
cv2_imshow(gray)
cv2_imshow(unchange)
# Out:
# <PIL.Image.Image image mode=RGB size=220x271 at 0x7FEB730DC630>
# <PIL.Image.Image image mode=L size=220x271 at 0x7FEB730DC5F8>
# <PIL.Image.Image image mode=RGBA size=220x271 at 0x7FEB730DC630>

# %%
unchange[0][0]
# Out:
# array([0, 0, 0, 0], dtype=uint8)

# %% [markdown]
# # 1.3 이미지 저장하기

# %%
import cv2

img = cv2.imread('lena.jpg', cv2.IMREAD_GRAYSCALE)
cv2.imwrite('lenagray.png', img)
# Out:
# True

# %%
import cv2
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
#print(flags)

# %% [markdown]
# # 1.4 matplotlib 으로 그리기

# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

img =cv2.imread('lena.jpg', cv2.IMREAD_COLOR)

plt.imshow(img)
plt.xticks([]) #x축 눈금
plt.yticks([]) #y축 눈금
plt.show()

# %% [markdown]
# *원본은 붉은색 계열인데, 결과는 파란색 계열로 나타납니다.
# *이유는 openCV는 BGR로 사용하지만, Matplotlib는 RGB로 이미지를 보여주기 때문입니다.
# *즉 결과 값은 3차원 배열의 값 중 첫 번째와 세 번째 배열값을 서로 바꿔 주어야 합니다.

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)

b, g, r = cv2.split(img)   #img 파일을 b,g, r로 분리
img2 = cv2.merge([r,g,b])   #b, r을 바꿔서 merge

plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # 3절 디지털 이미지와 컬러

# %% [markdown]
# #Binary Image

# %% [markdown]
# binary image는 pixel당 1bit로 표현하는 영상:
# 원본 이미지를 thresholding처리하여 binary image로 변환
#
#
# 0, 1, 로 표현됨.
# dithering: 밀도를 조절하여 밝기를 표현하는 방법, 밀도의 개수만큼 점을 찍는것.
